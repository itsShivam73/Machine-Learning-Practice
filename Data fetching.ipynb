# %% [markdown]
# Fetching data from kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
import pandas as pd

# %%
import requests
from io import StringIO

url = "https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# fetching data for a json file

# %%
df = pd.read_json('https://raw.githubusercontent.com/datablist/sample-csv-files/refs/heads/main/src/data/product_names.json')
df
# Out:
#                              0
# 0              Blender Blender
# 1                Trimmer Clock
# 2                 Router Phone
# 3                  Clock Brush
# 4                 Lock Bicycle
# ..                         ...
# 495                      Brush
# 496                    Freezer
# 497  Scanner Monitor Treadmill
# 498         Scooter Microphone
# 499         Radio Stove Shaver
#
# [500 rows x 1 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# Fetching data with using api

# %%
import requests
import json

url = 'https://twitter-api45.p.rapidapi.com/broadcast.php'

headers = {
    "Content - Type" : "application/json",
    "X-RapidAPI-Key": "7503d75717msh2142ac6a2325a92p117facjsnd474a5872eea",
    "X-RapidAPI-Host": "twitter-api45.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.status_code)
print(response.text)
data = response.json()
# Out:
# 200
# {"live":true,"spaces":{"id":"s","started":"s","created_at":"s","tags":"s","language":"s","locked":"s","total_watching":"s","watching":"s","web_watching":"s","status":"s","participants":[]}}

# %% [markdown]
# another example (cricbuzz datasets)

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/40381/hscard"

headers = {
	"x-rapidapi-key": "7503d75717msh2142ac6a2325a92p117facjsnd474a5872eea",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

data = response.json()

# %%
data
# Out:
# {'scorecard': [{'inningsid': 1,
#    'batsman': [{'id': 1114,
#      'balls': 5,
#      'runs': 5,
#      'fours': 1,
#      'sixes': 0,
#      'strkrate': '100',
#      'name': 'Stirling',
#      'nickname': '',
#      'iscaptain': False,
#      'iskeeper': False,
#      'outdec': 'lbw b Nisarg Patel',
#      'videotype': '',
#      'videourl': '',
#      'videoid': 0,
#      'planid': 0,
#      'imageid': 0,
#      'premiumvideourl': '',
#      'iscbplusfree': False,
#      'ispremiumfree': False,
#      'inmatchchange': '',
#      'isoverseas': False,
#      'playingxichange': ''},
#     {'id': 6710,
#      'balls': 5,
#      'runs': 10,
#      'fours': 2,
#      'sixes': 0,
#      'strkrate': '200',
#      'name': 'Balbirnie',
#      'nickname': '',
#      'iscaptain': True,
#      'iskeeper': False,
#      'outdec': 'c Sushant Modani b Netravalkar',
#      'videotype': '',
#      'videourl': '',
#      'videoid': 0,
#      'planid': 0,
#      'imageid': 0,
# ...

# %%
import pandas as pd
temp1 = pd.DataFrame(data['scorecard'][0]['batsman'])
temp2 = pd.DataFrame(data['scorecard'][1]['batsman'])
batsman = pd.concat([temp1, temp2], ignore_index=True)
batsman
# Out:
#        id  balls  runs  fours  sixes strkrate                 name  \
# 0    1114      5     5      1      0      100             Stirling
# 1    6710      5    10      2      0      200            Balbirnie
# 2   11131     56    84      9      3      150        Lorcan Tucker
# 3   18143     11    17      2      1   154.55       Curtis Campher
# 4    6471     10     5      0      0       50              Getkate
# 5   13309      5     4      0      0       80            Neil Rock
# 6   11129      3     1      0      0    33.33   William McClintock
# 7   10449      4     3      0      0       75           Mark Adair
# 8   12769     11    13      1      0   118.18           Simi Singh
# 9   10451      1     0      0      0        0       Barry McCarthy
# 10  11124      2     2      0      0      100       Benjamin White
# 11  22891     23    16      1      0    69.57        Ritwik Behera
# 12  22896     11    11      2      0      100           Ryan Scott
# ...

# %%
import pandas as pd
temp1 = pd.DataFrame(data['scorecard'][0]['bowler'])
temp2 = pd.DataFrame(data['scorecard'][1]['bowler'])
bowlers = pd.concat([temp1, temp2], ignore_index=True)
bowlers
# Out:
#        id overs  maidens  wickets  runs economy            name  \
# 0   15475     4        0        2    29     7.2    Nisarg Patel
# 1    9748   3.5        0        3    33     8.6     Netravalkar
# 2   11450     3        0        0    34    11.3        Ali Khan
# 3   22901     4        0        2    32       8  Yasir Mohammad
# 4   22531     3        0        2    16     5.3  Vatsal Vaghela
# 5   22891     1        0        0     5       5   Ritwik Behera
# 6   10449     4        0        1    25     6.2      Mark Adair
# 7   10451     4        0        0    24       6  Barry McCarthy
# 8   18143     4        1        4    25     6.2  Curtis Campher
# 9   12769     4        0        0    31     7.8      Simi Singh
# 10  11124     3        0        1    27       9  Benjamin White
# 11   1114     1        0        0     4       4   Paul Stirling
#
#           nickname  iscaptain  iskeeper  ... dots balls   rpb  planid  \
# ...
